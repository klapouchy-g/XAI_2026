# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Libraries

# %%
#pip install Librosa
# Out:
# Requirement already satisfied: Librosa in c:\users\shahe\anaconda\lib\site-packages (0.11.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (0.59.1)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (1.4.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (1.1.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\shahe\anaconda\lib\site-packages (from Librosa) (1.0.3)
# Requirement already satisfied: packaging in c:\users\shahe\anaconda\lib\site-packages (from lazy_loader>=0.1->Librosa) (23.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\shahe\anaconda\lib\site-packages (from numba>=0.51.0->Librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\shahe\anaconda\lib\site-packages (from pooch>=1.1->Librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\shahe\anaconda\lib\site-packages (from pooch>=1.1->Librosa) (2.32.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shahe\anaconda\lib\site-packages (from scikit-learn>=1.1.0->Librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\shahe\anaconda\lib\site-packages (from soundfile>=0.12.1->Librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\shahe\anaconda\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->Librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shahe\anaconda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->Librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shahe\anaconda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->Librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shahe\anaconda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->Librosa) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shahe\anaconda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->Librosa) (2026.4.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import librosa
import os
from sklearn.preprocessing import LabelEncoder

# %%
from pathlib import Path

cwd = Path.cwd()
path = cwd.parents[1] / "data" / "raw"  # up 2 levels, then /data/raw
processed_path = cwd.parents[1] / "data" / "processed"
processed_path.mkdir(parents=True, exist_ok=True)

# %%
ravdess_directory_list = os.listdir(path)
print(ravdess_directory_list)
file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    actor = os.listdir(path / dir)
    for file in actor:
        part = file.split('.')[0]
        part = file.split('-')
        file_emotion.append(int(part[2]))
        file_path.append(str(path / dir / file))
        
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

path_df = pd.DataFrame(file_path, columns=['Path'])
meta_df = pd.concat([emotion_df, path_df], axis=1)

meta_df['Emotions'] = meta_df['Emotions'].replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'})

label_encoder = LabelEncoder()

meta_df["Emotion_ID"] = label_encoder.fit_transform(meta_df["Emotions"])

print(label_encoder.classes_)

meta_df.head()
meta_df.to_csv(processed_path / "ravdess_metadata.csv", index=False)

meta_df['Emotions'].value_counts()
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24']
# ['angry' 'calm' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']
# Emotions
# calm        192
# happy       192
# sad         192
# angry       192
# fear        192
# disgust     192
# surprise    192
# neutral      96
# Name: count, dtype: int64

# %%
# Sample file to figure our sample rate and duration, from the output we know that the duration should be standardized and duration should be 48000 Hz
sample_path = meta_df["Path"].iloc[0]

audio, sr = librosa.load(sample_path, sr=None)

print("Sample rate:", sr)
print("Audio shape:", audio.shape)
print("Duration:", len(audio) / sr)
# Out:
# Sample rate: 48000
# Audio shape: (158558,)
# Duration: 3.3032916666666665

# %% [markdown]
# ## Standardizing duration and extracting features

# %%
sr = 48000
duration = 3
length = sr * duration

def standardize_length(audio, target_length):
    # If the audio is longer than 3 seconds we cut it the middle bit, since often the emotion is most clear in the middle and there may be a delay at the start of the recording.
    # If its shorter we add silence at the end (represented by 0 in this case)
    if len(audio) > target_length:
        start = (len(audio) - target_length) // 2
        return audio[start:start + target_length]
    else:
        return np.pad(audio, (0, target_length - len(audio)))

# %%
processed_audio = []
labels_text = []
labels_num = []

for audio_path, emotion, emotion_id in zip(meta_df["Path"], meta_df["Emotions"], meta_df["Emotion_ID"]):
    # Load audio and resample to target sample rate
    audio, _ = librosa.load(audio_path, sr=sr)

    audio = standardize_length(audio, length)

    audio = librosa.util.normalize(audio) # Normalizes volume to avoid noise from recording levels etc.

    processed_audio.append(audio)
    labels_text.append(emotion)
    labels_num.append(emotion_id)

print("Processed clips:", len(processed_audio))
print("Text Labels:", len(labels_text))
print("Numeric Labels:", len(labels_num))
# Out:
# Processed clips: 1440
# Text Labels: 1440
# Numeric Labels: 1440

# %%
X_audio = np.array(processed_audio)
y_text = np.array(labels_text)
y_encoded = np.array(labels_num)

# %%
n_mfcc = 40

mfcc_features = []

for audio in X_audio:
    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sr,
        n_mfcc=n_mfcc
    )
    
    # --- ORIGINAL ---
    mfcc_mean  = np.mean(mfcc, axis=1)          # (40,) mean across time

    # --- NEW: Standard Deviation ---
    mfcc_std   = np.std(mfcc, axis=1)           # (40,) variability across time

    # --- NEW: Delta (rate of change) ---
    mfcc_delta = librosa.feature.delta(mfcc)    # (40, 282) first derivative
    mfcc_delta_mean = np.mean(mfcc_delta, axis=1)  # (40,) mean of delta
    mfcc_delta_std  = np.std(mfcc_delta, axis=1)   # (40,) std of delta

    # --- Combine all into one vector ---
    combined = np.concatenate([
        mfcc_mean,        # 40 features
        mfcc_std,         # 40 features
        mfcc_delta_mean,  # 40 features
        mfcc_delta_std    # 40 features
    ])                    # total = 160 features

    mfcc_features.append(combined)

X_mfcc = np.array(mfcc_features)
print(X_mfcc.shape)                        # (1440, 160)
# Out:
# (1440, 160)

# %%
# Generate column names for all 160 features
feature_names = (
    [f"mfcc_mean_{i+1}"       for i in range(n_mfcc)] +   # 40
    [f"mfcc_std_{i+1}"        for i in range(n_mfcc)] +   # 40
    [f"mfcc_delta_mean_{i+1}" for i in range(n_mfcc)] +   # 40
    [f"mfcc_delta_std_{i+1}"  for i in range(n_mfcc)]     # 40
)                                                          # = 160 total

mfcc_df = pd.DataFrame(X_mfcc, columns=feature_names)

mfcc_df["Emotion"]    = y_text
mfcc_df["Emotion_ID"] = y_encoded
mfcc_df["Path"]       = meta_df["Path"].values

print(mfcc_df.shape)    # (1440, 163)  ← 160 features + 3 label columns
mfcc_df.head()
# Out:
# (1440, 163)
#    mfcc_mean_1  mfcc_mean_2  mfcc_mean_3  mfcc_mean_4  mfcc_mean_5  \
# 0  -398.042206    75.356049     3.555151    13.388279     6.033112
# 1  -404.414398    77.657196     1.182115    14.425774     8.691035
# 2  -423.030212    75.066856     3.681056    12.329444     6.456292
# 3  -431.444702    70.960457     5.918694    13.914023     6.412232
# 4  -374.966949    88.756744     6.575492    16.645142     7.118174
#
#    mfcc_mean_6  mfcc_mean_7  mfcc_mean_8  mfcc_mean_9  mfcc_mean_10  ...  \
# 0    15.046699    -3.274679     3.410381    -3.609158     -1.716895  ...
# 1    15.811256    -4.619638     4.848064    -4.008130     -4.158945  ...
# 2    11.320029    -3.664177     4.332827    -5.347966     -3.426528  ...
# 3    13.075801    -2.052994     5.827670    -5.217687     -3.630437  ...
# 4    16.783058    -3.964944     5.049708    -6.502435     -1.174364  ...
#
#    mfcc_delta_std_34  mfcc_delta_std_35  mfcc_delta_std_36  mfcc_delta_std_37  \
# 0           0.666572           0.683853           0.649953           0.690861
# 1           0.558050           0.517243           0.643897           0.560654
# 2           0.715581           0.730944           0.651703           0.507533
# 3           0.679620           0.560773           0.626818           0.622375
# 4           0.624812           0.677422           0.675885           0.721127
#
#    mfcc_delta_std_38  mfcc_delta_std_39  mfcc_delta_std_40  Emotion  \
# 0           0.616112           0.641250           0.650382  neutral
# 1           0.735399           0.663243           0.650409  neutral
# 2           0.522464           0.576221           0.716872  neutral
# 3           0.622986           0.500272           0.799045  neutral
# 4           0.824473           0.579583           0.562428     calm
#
#    Emotion_ID                                               Path
# 0           5  C:\Users\shahe\4XAI\Project\data\raw\Actor_01\...
# 1           5  C:\Users\shahe\4XAI\Project\data\raw\Actor_01\...
# 2           5  C:\Users\shahe\4XAI\Project\data\raw\Actor_01\...
# 3           5  C:\Users\shahe\4XAI\Project\data\raw\Actor_01\...
# 4           1  C:\Users\shahe\4XAI\Project\data\raw\Actor_01\...
#
# [5 rows x 163 columns]

# %%
mfcc_df.to_csv(processed_path / "ravdess_mfcc_features_v2.csv", index=False)
print("Saved updated features with shape:", X_mfcc.shape)
# Out:
# Saved updated features with shape: (1440, 160)

# %% [markdown]
# ## Additional preprocessing for CNN

# %%
n_mels = 128
# For Grad-cam we need to convert the .wav files into spectograms, since the model expects 2D input.
def extract_mel_spectrogram(audio, sr, n_mels=n_mels):
    mel_spec = librosa.feature.melspectrogram(
        y=audio,
        sr=sr,
        n_mels=n_mels
    )
    
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    
    return mel_spec_db

# %%
mel_spectrograms = []

for audio in X_audio:
    mel_spec = extract_mel_spectrogram(audio, sr)
    mel_spectrograms.append(mel_spec)

X_mel = np.array(mel_spectrograms)

print("Mel spectrogram array shape:", X_mel.shape)

X_mel_cnn = X_mel[..., np.newaxis]

print("CNN input shape:", X_mel_cnn.shape)
# Out:
# Mel spectrogram array shape: (1440, 128, 282)
# CNN input shape: (1440, 128, 282, 1)

# %%
np.save(processed_path / "ravdess_mel_spectrograms.npy", X_mel_cnn)
np.save(processed_path / "ravdess_emotion_labels_encoded.npy", y_encoded)
np.save(processed_path / "ravdess_emotion_classes.npy", label_encoder.classes_)

X_loaded = np.load(processed_path / "ravdess_mel_spectrograms.npy")
y_loaded = np.load(processed_path / "ravdess_emotion_labels_encoded.npy")

print("Loaded Mel spectrograms shape:", X_loaded.shape)
print("Loaded labels shape:", y_loaded.shape)
# Out:
# Loaded Mel spectrograms shape: (1440, 128, 282, 1)
# Loaded labels shape: (1440,)
